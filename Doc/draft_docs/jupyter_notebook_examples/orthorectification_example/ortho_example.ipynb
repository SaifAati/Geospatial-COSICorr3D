# %% [markdown]
# # Orthorectification

# %% [markdown]
# ## 1. Import classes and functions

# %%
from geoCosiCorr3D.geoCosiCorr3D_scripts.script_orthorectification import *

# %% [markdown]
# ## 2. Running the code

# %% [markdown]
# #### Paths input parameters
# Before running the code, write the paths of the files that contains the input parameters and the configuration of the code:
# - inputs_file = ‘home/...’: write the path to assign inputs_file to the document containing the input parameters: input_izmit.json, input_izmit_GCPS.json, input_izmit_DEM.json or
# input_izmit_correction_model_file.json in this example. Modify the input parameters directly in the document containing the input parameters.
# - config_file = ‘.../geo_ortho_config.yaml’ : write the path to assign geo_ortho_config.yaml to config_file. Modify the configuration of the code directly in geo_ortho_config.yaml.

# %%
if __name__ == '__main__':

    # Paths input parameters
    inputs_file = '/home/mcadoux/PycharmProjects/Geospatial-COSICorr3D/geoCosiCorr3D_examples/orthorectification_example/input_izmit_correction_model_file.json'
    config_file = "/home/mcadoux/PycharmProjects/Geospatial-COSICorr3D/geoCosiCorr3D/geoCore/geoCosiCorrBaseCfg/geo_ortho_config.yaml"

    # Running the code
    main_geoOrtho(input_file=inputs_file, config_file=config_file)
# Out:
# 2023-08-04 11:34:29,037 [INFO] ortho inputs:{'raw_img_path': ['/home/mcadoux/PycharmProjects/Geospatial-COSICorr3D/geoCosiCorr3D_examples/orthorectification_example/SP2_DS/003-006_S2_103-268-0_1998-06-10-09-01-06_HRV-1_P_DT_TT/IMAGERY.TIF', '/home/mcadoux/PycharmProjects/Geospatial-COSICorr3D/geoCosiCorr3D_examples/orthorectification_example/SP2_DS/003-008_S2_103-268-0_1998-03-03-09-05-04_HRV-1_P_DT_TT/SCENE01/IMAGERY.TIF', '/home/mcadoux/PycharmProjects/Geospatial-COSICorr3D/geoCosiCorr3D_examples/orthorectification_example/SP2_DS/003-008_S2_103-268-0_1998-04-03-09-08-28_HRV-1_P_DT_TT/SCENE01/IMAGERY.TIF'], 'metadata_file_path': ['/home/mcadoux/PycharmProjects/Geospatial-COSICorr3D/geoCosiCorr3D_examples/orthorectification_example/SP2_DS/003-006_S2_103-268-0_1998-06-10-09-01-06_HRV-1_P_DT_TT/METADATA.DIM', '/home/mcadoux/PycharmProjects/Geospatial-COSICorr3D/geoCosiCorr3D_examples/orthorectification_example/SP2_DS/003-008_S2_103-268-0_1998-03-03-09-05-04_HRV-1_P_DT_TT/SCENE01/METADA
# ...
